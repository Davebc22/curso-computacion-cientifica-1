# %% [markdown]
# # 1. Realiza un algoritmo que transforme numeros decimales a numeros binarios

# %%
#Testing git interaction
print('Hola mundo')
# Out:
# Hola mundo

# %% [markdown]
# # 2. Realiza un algoritmo que transforme numeros binarios a numeros decimales

# %% [markdown]
# # 3. Realiza un algoritmo que transforme numeros romanos a numeros decimales

# %% [markdown]
# # 4. Realiza un algoritmo que transforme numeros decimales a numeros romanos

# %% [markdown]
# # 5. Realiza un algoritmo que valide si una frase es un palindromo

# %% [markdown]
# # 6. Realiza un algoritmo que cuente la cantidad de ocurrencias de cada caracter en una frase

# %% [markdown]
# # 7. Realiza un algoritmo que tome como entrada 3 puntos x,y del plano cartesiano, formando un triangulo, como salida el programa calcule al area y perimetro

# %% [markdown]
# # 8. Realiza un algoritmo que valide si un email es valido
# ### El texto debe tener un nombre de usuario sin caracteres especiales, el símbolo @, un dominio y una extensión como .com

# %% [markdown]
# # 9. Compresor y Descompresor de Cadenas por RLE con Anidamiento Sencillo
#
# ### Implementar la codificación Run-Length Encoding (RLE) expandida
# Convierte la cadena "AAABBCDDDD" en "A3B2C1D4"

# %% [markdown]
# # 10. Conjetura de Collatz
#
# ### Implementa un algoritmo que genere y grafique la siguiente secuencia, iniciando desde un numero entero positivo cualquiera
#
# - Si el ultimo numero n es par, el siguiente es: n/2
# - Si el ultimo numero n es impar, el siguiente es: 3*n+1

# %% [markdown]
# # 11. Genere el histograma que resulta de simular la suma del lanzamiento de 2 dados de 6 caras, genere esto para un N numero de repeticiones del experimento

# %% [markdown]
# # 12. Implemente un algoritmo que como entrada reciba una lista de numeros, y un numero T objetivo. Como salida el algoritmo debe encontrar grupos de 3 numeros que sumen el numero T objetivo

# %% [markdown]
# # 13. Implemente un algoritmo que transforme codigo morse a letras

# %% [markdown]
# # 14. Implemente un algoritmo que transforme letras a codigo morse

# %% [markdown]
# # 15. Implemente un algoritmo que encuentre los numeros primos gemelos en un rango de numeros. Estos son números primos separados por un número (es decir, que tienen una diferencia de 2 unidades y un número compuesto en medio)
#
# ejemplo: 11 y 13 son numeros primos gemelos
